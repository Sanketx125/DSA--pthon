# %% [markdown]
# ## Stack Using Inheritated List

# %% [markdown]
# Assignment :
#
# ![image.png](attachment:f19c1664-5d45-4200-86d9-b291fb7809c4.png)

# %%
class Stack (list):   # list is inheritaed  

    # now here if we create a object class this is also object of list because list is inherited

    def is_empty(self):
        return len(self) == 0

    def push(self, data):
        self.append(data)

    def pop(self):                  
        if not self.is_empty():
            super().pop()           # here over
        else:
            raise IndexError("List is Empty")

    def peek(self):
        if not self.is_empty():
            return self[-1]
        else:
            raise IndexError("List is Empty")

    def get_size(self):
        return len(self)

    def insert(self, index, data):
        raise AttributeError("insert is not part of stack")

# %%
s = Stack()

# %%
s.append(10)

# %%
s.peek()
# Out:
# 10

# %%
s.get_size()
# Out:
# 1

# %%
s.insert(2, 10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 s.insert(2, 10)
#
# Cell In[11], line 27, in Stack.insert(self, index, data)
#      26 def insert(self, index, data):
# ---> 27     raise AttributeError("insert is not part of stack")
#
# AttributeError: insert is not part of stack
