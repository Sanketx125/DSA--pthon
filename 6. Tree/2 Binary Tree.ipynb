# %% [markdown]
# # Binary Tree:

# %% [markdown]
# A tree which contain at most 2 nodes is called Binary Tree.
#
# ![image.png](attachment:7ede8bf5-ead0-4388-ad23-01b8c4e839b9.png)

# %% [markdown]
# #### 1. Complete Binary Tree:
# * all levels are completely filled is called.
# *
# ![image.png](attachment:41d10e56-8630-4f21-a05c-e61dfe50471e.png)
# ----

# %% [markdown]
# #### 2. Almost Complete Binary Tree:
# * The tree is similar to a complete binary tree but may have some nodes missing at the bottom level, still ensuring that all nodes are as far left as possible.
# * The last level has nodes filled from left to right.
#
# *  ![image.png](attachment:5ee7515f-6c20-46fd-8000-5f0dfaa5e22d.png)
#
# ---

# %% [markdown]
# #### 3. Strict Binary Tree:
# * Each node of Strict Binary Tree whill have either 0 or 2 childrenes. full binary tree.
#
# ![image.png](attachment:cfedd554-0cce-4898-becb-47ee221d31e7.png)
#
# ---

# %% [markdown]
# ## Representation of Binary Tree:
# * There are two possible representations of Binary Tree:
#      * Array Representation  (rarely used)
#      * Linked Representation  (by default)

# %% [markdown]
# ## A] Linked Representation:
#
# * ![image.png](attachment:54b80cec-4592-43ed-8750-912125823dec.png)
#
# * ![image.png](attachment:11c552f7-86df-41dd-9460-8b9859899248.png)

# %% [markdown]
# -------
#
# ========
# ## Note-
#
# ========
#
# * the binary tree doesnt have any specifice rule to insert item.
# * that why binary do not use in implementation.
# * always prefered Binary Search Tree for that because binary search tree has some rules.
